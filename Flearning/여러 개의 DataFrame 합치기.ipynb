# %%
############# 데이터 처리하기 1강 - 여러 개의 DataFrame 합치기

# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.DataFrame({"key": list("bbacaab"),
                    "data1": range(7)})
df2 = pd.DataFrame({"key":list("abd"),
                    "data2":range(3)})

# %%
df1
# Out:
#    data1 key
# 0      0   b
# 1      1   b
# 2      2   a
# 3      3   c
# 4      4   a
# 5      5   a
# 6      6   b

# %%
df2
# Out:
#    data2 key
# 0      0   a
# 1      1   b
# 2      2   d

# %%
pd.merge(df1, df2, on="key") # inner join 개념
# Out:
#    data1 key  data2
# 0      0   b      1
# 1      1   b      1
# 2      6   b      1
# 3      2   a      0
# 4      4   a      0
# 5      5   a      0

# %%
pd.merge(df1, df2, on="key", how="outer") # outer join
# Out:
#    data1 key  data2
# 0    0.0   b    1.0
# 1    1.0   b    1.0
# 2    6.0   b    1.0
# 3    2.0   a    0.0
# 4    4.0   a    0.0
# 5    5.0   a    0.0
# 6    3.0   c    NaN
# 7    NaN   d    2.0

# %%
pd.merge?

# %%
pd.merge(df1, df2, on="key", how="left") # df1 기준
# Out:
#    data1 key  data2
# 0      0   b    1.0
# 1      1   b    1.0
# 2      2   a    0.0
# 3      3   c    NaN
# 4      4   a    0.0
# 5      5   a    0.0
# 6      6   b    1.0

# %%
pd.merge(df1, df2, on="key", how="right") # df2 기준
# Out:
#    data1 key  data2
# 0    0.0   b      1
# 1    1.0   b      1
# 2    6.0   b      1
# 3    2.0   a      0
# 4    4.0   a      0
# 5    5.0   a      0
# 6    NaN   d      2

# %%
df1 = pd.DataFrame({"key":list("bbacab"),
                    "data1":range(6)})
df2 = pd.DataFrame({"key":list("ababd"),
                    "data2":range(5)})

# %%
df1
# Out:
#    data1 key
# 0      0   b
# 1      1   b
# 2      2   a
# 3      3   c
# 4      4   a
# 5      5   b

# %%
df2
# Out:
#    data2 key
# 0      0   a
# 1      1   b
# 2      2   a
# 3      3   b
# 4      4   d

# %%
pd.merge(df1, df2, on="key", how="inner")
# Out:
#    data1 key  data2
# 0      0   b      1
# 1      0   b      3
# 2      1   b      1
# 3      1   b      3
# 4      5   b      1
# 5      5   b      3
# 6      2   a      0
# 7      2   a      2
# 8      4   a      0
# 9      4   a      2

# %%
df3 = pd.DataFrame({"lkey": list("bbacaab"),
                    "data1":range(7)})
df4 = pd.DataFrame({"rkey": list("abd"),
                    "data2":range(3)})

# %%
df3
# Out:
#    data1 lkey
# 0      0    b
# 1      1    b
# 2      2    a
# 3      3    c
# 4      4    a
# 5      5    a
# 6      6    b

# %%
df4
# Out:
#    data2 rkey
# 0      0    a
# 1      1    b
# 2      2    d

# %%
pd.merge(df3, df4, left_on="lkey", right_on="rkey")
# Out:
#    data1 lkey  data2 rkey
# 0      0    b      1    b
# 1      1    b      1    b
# 2      6    b      1    b
# 3      2    a      0    a
# 4      4    a      0    a
# 5      5    a      0    a

# %%
left1 = pd.DataFrame({"key":['a','b','a','a','b','c'],'value':range(6)})
right1 = pd.DataFrame({'group_val':[3.5, 7]}, index=['a','b'])

# %%
left1
# Out:
#   key  value
# 0   a      0
# 1   b      1
# 2   a      2
# 3   a      3
# 4   b      4
# 5   c      5

# %%
right1
# Out:
#    group_val
# a        3.5
# b        7.0

# %%
pd.merge(left1, right1, left_on="key", right_index=True)
# Out:
#   key  value  group_val
# 0   a      0        3.5
# 2   a      2        3.5
# 3   a      3        3.5
# 1   b      1        7.0
# 4   b      4        7.0

# %%
pd.merge(right1, left1, left_index=True, right_on="key")
# Out:
#    group_val key  value
# 0        3.5   a      0
# 2        3.5   a      2
# 3        3.5   a      3
# 1        7.0   b      1
# 4        7.0   b      4

# %%
left2 = pd.DataFrame([ [1.,2.], [3.,4.], [5.,6.] ],
                     index=['a','c','e'], columns=['Seoul', 'Incheon'])
right2 = pd.DataFrame([ [7.,8.], [9., 10.], [11., 12.], [13,14] ],
                     index=['b','c','d','e'], columns=['Daegu', 'Ulsan'])

# %%
left2
# Out:
#    Seoul  Incheon
# a    1.0      2.0
# c    3.0      4.0
# e    5.0      6.0

# %%
right2
# Out:
#    Daegu  Ulsan
# b    7.0    8.0
# c    9.0   10.0
# d   11.0   12.0
# e   13.0   14.0

# %%
pd.merge(left2, right2, how="outer", left_index=True, right_index=True)
# Out:
#    Seoul  Incheon  Daegu  Ulsan
# a    1.0      2.0    NaN    NaN
# b    NaN      NaN    7.0    8.0
# c    3.0      4.0    9.0   10.0
# d    NaN      NaN   11.0   12.0
# e    5.0      6.0   13.0   14.0

# %%
s1 = pd.Series([0,1], index=["a","b"])
s2 = pd.Series([2,3,4], index=["c","d","e"])
s3 = pd.Series([5,6], index=["f","g"])

# %%
s1
# Out:
# a    0
# b    1
# dtype: int64

# %%
s2
# Out:
# c    2
# d    3
# e    4
# dtype: int64

# %%
s3
# Out:
# f    5
# g    6
# dtype: int64

# %%
pd.concat([s1,s2,s3])
# Out:
# a    0
# b    1
# c    2
# d    3
# e    4
# f    5
# g    6
# dtype: int64

# %%
pd.concat([s1,s2,s3], axis=1)
# Out:
#      0    1    2
# a  0.0  NaN  NaN
# b  1.0  NaN  NaN
# c  NaN  2.0  NaN
# d  NaN  3.0  NaN
# e  NaN  4.0  NaN
# f  NaN  NaN  5.0
# g  NaN  NaN  6.0

# %%
s4 = pd.concat([s1*5,s3])

# %%
s4
# Out:
# a    0
# b    5
# f    5
# g    6
# dtype: int64

# %%
pd.concat([s1,s4], axis=1)
# Out:
#      0  1
# a  0.0  0
# b  1.0  5
# f  NaN  5
# g  NaN  6

# %%
pd.concat([s1,s2,s3], axis=1, keys=["one","two","three"])
# Out:
#    one  two  three
# a  0.0  NaN    NaN
# b  1.0  NaN    NaN
# c  NaN  2.0    NaN
# d  NaN  3.0    NaN
# e  NaN  4.0    NaN
# f  NaN  NaN    5.0
# g  NaN  NaN    6.0

# %%
df1 = pd.DataFrame(np.arange(6).reshape(3,2),
                   index=['a','b','c'], columns=["one",'two'])
df2 = pd.DataFrame(5 + np.arange(4).reshape(2,2),
                   index=['a','c'], columns=['three','four'])

# %%
df1
# Out:
#    one  two
# a    0    1
# b    2    3
# c    4    5

# %%
df2
# Out:
#    three  four
# a      5     6
# c      7     8

# %%
pd.concat([df1,df2], axis=1)
# Out:
#    one  two  three  four
# a    0    1    5.0   6.0
# b    2    3    NaN   NaN
# c    4    5    7.0   8.0

# %%
df3 = pd.DataFrame(np.random.randn(3,4), columns=['a','b','c','d'])
df4 = pd.DataFrame(np.random.randn(2,3), columns=['b','d','a'])

# %%
df3
# Out:
#           a         b         c         d
# 0  0.016788 -0.078632  0.351889  0.382554
# 1  0.602343 -0.231434  0.357599  1.088928
# 2  0.752647  0.148453 -0.922910 -1.105014

# %%
df4
# Out:
#           b         d         a
# 0 -1.490437 -1.807412  2.374243
# 1 -1.124836  0.360898  1.470740

# %%
pd.concat([df3,df4])
# Out:
#           a         b         c         d
# 0  0.016788 -0.078632  0.351889  0.382554
# 1  0.602343 -0.231434  0.357599  1.088928
# 2  0.752647  0.148453 -0.922910 -1.105014
# 0  2.374243 -1.490437       NaN -1.807412
# 1  1.470740 -1.124836       NaN  0.360898

# %%
pd.concat([df3,df4], ignore_index=True)
# Out:
#           a         b         c         d
# 0  0.016788 -0.078632  0.351889  0.382554
# 1  0.602343 -0.231434  0.357599  1.088928
# 2  0.752647  0.148453 -0.922910 -1.105014
# 3  2.374243 -1.490437       NaN -1.807412
# 4  1.470740 -1.124836       NaN  0.360898

# %%
############# 데이터 처리하기 1강 - 여러 개의 DataFrame 합치기

import numpy as np
import pandas as pd

df1 = pd.DataFrame({"key": list("bbacaab"),
                    "data1": range(7)})
df2 = pd.DataFrame({"key":list("abd"),
                    "data2":range(3)})

df1

df2

pd.merge(df1, df2, on="key") # inner join 개념

pd.merge(df1, df2, on="key", how="outer") # outer join

pd.merge?

pd.merge(df1, df2, on="key", how="left") # df1 기준

pd.merge(df1, df2, on="key", how="right") # df2 기준

df1 = pd.DataFrame({"key":list("bbacab"),
                    "data1":range(6)})
df2 = pd.DataFrame({"key":list("ababd"),
                    "data2":range(5)})

df1

df2

pd.merge(df1, df2, on="key", how="inner")

df3 = pd.DataFrame({"lkey": list("bbacaab"),
                    "data1":range(7)})
df4 = pd.DataFrame({"rkey": list("abd"),
                    "data2":range(3)})

df3

df4

pd.merge(df3, df4, left_on="lkey", right_on="rkey")

left1 = pd.DataFrame({"key":['a','b','a','a','b','c'],'value':range(6)})
right1 = pd.DataFrame({'group_val':[3.5, 7]}, index=['a','b'])

left1

right1

pd.merge(left1, right1, left_on="key", right_index=True)

pd.merge(right1, left1, left_index=True, right_on="key")

left2 = pd.DataFrame([ [1.,2.], [3.,4.], [5.,6.] ],
                     index=['a','c','e'], columns=['Seoul', 'Incheon'])
right2 = pd.DataFrame([ [7.,8.], [9., 10.], [11., 12.], [13,14] ],
                     index=['b','c','d','e'], columns=['Daegu', 'Ulsan'])

left2

right2

pd.merge(left2, right2, how="outer", left_index=True, right_index=True)

s1 = pd.Series([0,1], index=["a","b"])
s2 = pd.Series([2,3,4], index=["c","d","e"])
s3 = pd.Series([5,6], index=["f","g"])

s1

s2 

s3

pd.concat([s1,s2,s3])

pd.concat([s1,s2,s3], axis=1)

s4 = pd.concat([s1*5,s3])

s4

pd.concat([s1,s4], axis=1)

pd.concat([s1,s2,s3], axis=1, keys=["one","two","three"])

df1 = pd.DataFrame(np.arange(6).reshape(3,2),
                   index=['a','b','c'], columns=["one",'two'])
df2 = pd.DataFrame(5 + np.arange(4).reshape(2,2),
                   index=['a','c'], columns=['three','four'])

df1

df2 

pd.concat([df1,df2], axis=1)

df3 = pd.DataFrame(np.random.randn(3,4), columns=['a','b','c','d'])
df4 = pd.DataFrame(np.random.randn(2,3), columns=['b','d','a'])

df3

df4

pd.concat([df3,df4])

pd.concat([df3,df4], ignore_index=True)
